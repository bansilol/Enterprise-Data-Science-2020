# %%
import pandas as pd
import numpy as np
from datetime import datetime

pd.set_option('display.max_rows',500)

# %%
data_path= '../data/raw/COVID-19/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_confirmed_global.csv'
pd_raw=pd.read_csv(data_path)

# %%
pd_raw.head()
# Out:
#   Province/State Country/Region       Lat       Long  1/22/20  1/23/20  \
# 0            NaN    Afghanistan  33.93911  67.709953        0        0
# 1            NaN        Albania  41.15330  20.168300        0        0
# 2            NaN        Algeria  28.03390   1.659600        0        0
# 3            NaN        Andorra  42.50630   1.521800        0        0
# 4            NaN         Angola -11.20270  17.873900        0        0
#
#    1/24/20  1/25/20  1/26/20  1/27/20  ...  8/28/20  8/29/20  8/30/20  \
# 0        0        0        0        0  ...    38140    38143    38162
# 1        0        0        0        0  ...     9195     9279     9380
# 2        0        0        0        0  ...    43403    43781    44146
# 3        0        0        0        0  ...     1124     1124     1124
# 4        0        0        0        0  ...     2471     2551     2624
#
#    8/31/20  9/1/20  9/2/20  9/3/20  9/4/20  9/5/20  9/6/20
# ...

# %%
pd_raw.columns[4:]
# Out:
# Index(['1/22/20', '1/23/20', '1/24/20', '1/25/20', '1/26/20', '1/27/20',
#        '1/28/20', '1/29/20', '1/30/20', '1/31/20',
#        ...
#        '8/28/20', '8/29/20', '8/30/20', '8/31/20', '9/1/20', '9/2/20',
#        '9/3/20', '9/4/20', '9/5/20', '9/6/20'],
#       dtype='object', length=229)

# %%
time_idx=pd_raw.columns[4:]

# %%
df_plot = pd.DataFrame({
    'date' : time_idx})
df_plot.head()
# Out:
#       date
# 0  1/22/20
# 1  1/23/20
# 2  1/24/20
# 3  1/25/20
# 4  1/26/20

# %%
pd_raw['Country/Region']
# Out:
# 0                           Afghanistan
# 1                               Albania
# 2                               Algeria
# 3                               Andorra
# 4                                Angola
# 5                   Antigua and Barbuda
# 6                             Argentina
# 7                               Armenia
# 8                             Australia
# 9                             Australia
# 10                            Australia
# 11                            Australia
# 12                            Australia
# 13                            Australia
# 14                            Australia
# 15                            Australia
# 16                              Austria
# 17                           Azerbaijan
# 18                              Bahamas
# 19                              Bahrain
# 20                           Bangladesh
# 21                             Barbados
# 22                              Belarus
# ...

# %%
pd_raw[pd_raw['Country/Region']=='Germany'].iloc[:,4::].sum(axis=0)[0:4]
# Out:
# 1/22/20    0
# 1/23/20    0
# 1/24/20    0
# 1/25/20    0
# dtype: int64

# %%
country_list=['Italy', 'US', 'Spain', 'Germany', 'Korea/South']

# %%
for each in country_list:
    df_plot[each]=np.array(pd_raw[pd_raw['Country/Region']==each].iloc[:,4::].sum(axis=0))

# %%
df_plot
# Out:
#         date   Italy       US   Spain  Germany  Korea/South
# 0    1/22/20       0        1       0        0            0
# 1    1/23/20       0        1       0        0            0
# 2    1/24/20       0        2       0        0            0
# 3    1/25/20       0        2       0        0            0
# 4    1/26/20       0        5       0        0            0
# 5    1/27/20       0        5       0        1            0
# 6    1/28/20       0        5       0        4            0
# 7    1/29/20       0        5       0        4            0
# 8    1/30/20       0        5       0        4            0
# 9    1/31/20       2        7       0        5            0
# 10    2/1/20       2        8       1        8            0
# 11    2/2/20       2        8       1       10            0
# 12    2/3/20       2       11       1       12            0
# 13    2/4/20       2       11       1       12            0
# 14    2/5/20       2       11       1       12            0
# ...

# %%
# %matplotlib inline
df_plot.set_index('date').plot()

# %% [markdown]
# # Data Type Date

# %%
df_plot.head()
# Out:
#       date  Italy  US  Spain  Germany  Korea/South
# 0  1/22/20      0   1      0        0            0
# 1  1/23/20      0   1      0        0            0
# 2  1/24/20      0   2      0        0            0
# 3  1/25/20      0   2      0        0            0
# 4  1/26/20      0   5      0        0            0

# %%
time_idxs=[datetime.strptime( each, "%m/%d/%y") for each in df_plot.date] #convert to datetime
time_str=[each.strftime('%Y-%m-%d') for each in time_idxs] #convert to ISO norm

# %%
df_plot['date']=time_idxs
type(df_plot['date'][0])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
df_plot.head()
# Out:
#         date  Italy  US  Spain  Germany  Korea/South
# 0 2020-01-22      0   1      0        0            0
# 1 2020-01-23      0   1      0        0            0
# 2 2020-01-24      0   2      0        0            0
# 3 2020-01-25      0   2      0        0            0
# 4 2020-01-26      0   5      0        0            0

# %%
df_plot.to_csv('../data/processed/COVID_small.csv', sep=';', index=False)

# %% [markdown]
# # Relational Data Model - Defining a Primary Key

# %%
data_path= '../data/raw/COVID-19/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_confirmed_global.csv'
pd_raw=pd.read_csv(data_path)

# %%
pd_raw.head()
# Out:
#   Province/State Country/Region       Lat       Long  1/22/20  1/23/20  \
# 0            NaN    Afghanistan  33.93911  67.709953        0        0
# 1            NaN        Albania  41.15330  20.168300        0        0
# 2            NaN        Algeria  28.03390   1.659600        0        0
# 3            NaN        Andorra  42.50630   1.521800        0        0
# 4            NaN         Angola -11.20270  17.873900        0        0
#
#    1/24/20  1/25/20  1/26/20  1/27/20  ...  8/28/20  8/29/20  8/30/20  \
# 0        0        0        0        0  ...    38140    38143    38162
# 1        0        0        0        0  ...     9195     9279     9380
# 2        0        0        0        0  ...    43403    43781    44146
# 3        0        0        0        0  ...     1124     1124     1124
# 4        0        0        0        0  ...     2471     2551     2624
#
#    8/31/20  9/1/20  9/2/20  9/3/20  9/4/20  9/5/20  9/6/20
# ...

# %%
pd_data_base=pd_raw.rename(columns={'Country/Region': 'country', 'Province/State': 'state'})

# %%
pd_data_base=pd_data_base.drop(['Lat', 'Long'], axis=1)
pd_data_base.head()
# Out:
#   state      country  1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  \
# 0   NaN  Afghanistan        0        0        0        0        0        0
# 1   NaN      Albania        0        0        0        0        0        0
# 2   NaN      Algeria        0        0        0        0        0        0
# 3   NaN      Andorra        0        0        0        0        0        0
# 4   NaN       Angola        0        0        0        0        0        0
#
#    1/28/20  1/29/20  ...  8/28/20  8/29/20  8/30/20  8/31/20  9/1/20  9/2/20  \
# 0        0        0  ...    38140    38143    38162    38165   38196   38243
# 1        0        0  ...     9195     9279     9380     9513    9606    9728
# 2        0        0  ...    43403    43781    44146    44494   44833   45158
# 3        0        0  ...     1124     1124     1124     1176    1184    1199
# 4        0        0  ...     2471     2551     2624     2654    2729    2777
#
#    9/3/20  9/4/20  9/5/20  9/6/20
# ...

# %%
pd_data_base.set_index(['state','country'])
# Out:
#                                                                    1/22/20  \
# state                            country
# NaN                              Afghanistan                             0
#                                  Albania                                 0
#                                  Algeria                                 0
#                                  Andorra                                 0
#                                  Angola                                  0
#                                  Antigua and Barbuda                     0
#                                  Argentina                               0
#                                  Armenia                                 0
# Australian Capital Territory     Australia                               0
# New South Wales                  Australia                               0
# Northern Territory               Australia                               0
# ...

# %%
pd_data_base.set_index(['state','country']).T
# Out:
# state           NaN                                                     \
# country Afghanistan Albania Algeria Andorra Angola Antigua and Barbuda
# 1/22/20           0       0       0       0      0                   0
# 1/23/20           0       0       0       0      0                   0
# 1/24/20           0       0       0       0      0                   0
# 1/25/20           0       0       0       0      0                   0
# 1/26/20           0       0       0       0      0                   0
# 1/27/20           0       0       0       0      0                   0
# 1/28/20           0       0       0       0      0                   0
# 1/29/20           0       0       0       0      0                   0
# 1/30/20           0       0       0       0      0                   0
# 1/31/20           0       0       0       0      0                   0
# 2/1/20            0       0       0       0      0                   0
# ...

# %%
test_pd=pd_data_base.set_index(['state','country']).T
test_pd.columns
# Out:
# MultiIndex([(                           nan,         'Afghanistan'),
#             (                           nan,             'Albania'),
#             (                           nan,             'Algeria'),
#             (                           nan,             'Andorra'),
#             (                           nan,              'Angola'),
#             (                           nan, 'Antigua and Barbuda'),
#             (                           nan,           'Argentina'),
#             (                           nan,             'Armenia'),
#             ('Australian Capital Territory',           'Australia'),
#             (             'New South Wales',           'Australia'),
#             ...
#             (                           nan,      'United Kingdom'),
#             (                           nan,             'Uruguay'),
#             (                           nan,          'Uzbekistan'),
# ...

# %%
test_pd.stack(level=[0,1]).reset_index()
# Out:
#         level_0     state             country        0
# 0       1/22/20       NaN         Afghanistan      0.0
# 1       1/22/20       NaN             Albania      0.0
# 2       1/22/20       NaN             Algeria      0.0
# 3       1/22/20       NaN             Andorra      0.0
# 4       1/22/20       NaN              Angola      0.0
# ...         ...       ...                 ...      ...
# 103503   9/6/20  Zhejiang  West Bank and Gaza  26127.0
# 103504   9/6/20  Zhejiang      Western Sahara     10.0
# 103505   9/6/20  Zhejiang               Yemen   1987.0
# 103506   9/6/20  Zhejiang              Zambia  12776.0
# 103507   9/6/20  Zhejiang            Zimbabwe   6837.0
#
# [103508 rows x 4 columns]

# %%
test_pd.stack(level=[0,1]).reset_index().rename(columns={'level_0': 'date', 0:'confirmed'})
# Out:
#            date     state             country  confirmed
# 0       1/22/20       NaN         Afghanistan        0.0
# 1       1/22/20       NaN             Albania        0.0
# 2       1/22/20       NaN             Algeria        0.0
# 3       1/22/20       NaN             Andorra        0.0
# 4       1/22/20       NaN              Angola        0.0
# ...         ...       ...                 ...        ...
# 103503   9/6/20  Zhejiang  West Bank and Gaza    26127.0
# 103504   9/6/20  Zhejiang      Western Sahara       10.0
# 103505   9/6/20  Zhejiang               Yemen     1987.0
# 103506   9/6/20  Zhejiang              Zambia    12776.0
# 103507   9/6/20  Zhejiang            Zimbabwe     6837.0
#
# [103508 rows x 4 columns]

# %%
pd_relational_model=test_pd.stack(level=[0,1]).reset_index().rename(columns={'level_0': 'date', 0:'confirmed'})
pd_relational_model.head()
# Out:
#       date state      country  confirmed
# 0  1/22/20   NaN  Afghanistan        0.0
# 1  1/22/20   NaN      Albania        0.0
# 2  1/22/20   NaN      Algeria        0.0
# 3  1/22/20   NaN      Andorra        0.0
# 4  1/22/20   NaN       Angola        0.0

# %%
pd_relational_model.dtypes
# Out:
# date          object
# state         object
# country       object
# confirmed    float64
# dtype: object

# %%
pd_relational_model['date']=pd_relational_model.date.astype('datetime64[ns]')

# %%
pd_relational_model.dtypes
# Out:
# date         datetime64[ns]
# state                object
# country              object
# confirmed           float64
# dtype: object

# %%
pd_relational_model.to_csv('../data/processed/COVID_relational_confirmed.csv', sep=';', index=False)

# %% [markdown]
# # Group-by apply

# %%
pd_JH_data=pd.read_csv('../data/processed/COVID_relational_confirmed.csv', sep=';' ,parse_dates=[0])
pd_JH_data=pd_JH_data.sort_values('date', ascending=True).reset_index(drop=True).copy()
pd_JH_data.head()
# Out:
#         date     state        country  confirmed
# 0 2020-01-22       NaN    Afghanistan        0.0
# 1 2020-01-22  Zhejiang           Cuba        0.0
# 2 2020-01-22  Zhejiang        Croatia        0.0
# 3 2020-01-22  Zhejiang  Cote d'Ivoire        0.0
# 4 2020-01-22  Zhejiang     Costa Rica        0.0

# %%
test_data=pd_JH_data[((pd_JH_data['country']=='US')| (pd_JH_data['country']=='Germany'))& (pd_JH_data['date']>'2020-07-20')]

# %%
test_data
# Out:
#              date     state  country  confirmed
# 81846  2020-07-21  Zhejiang  Germany   203717.0
# 81965  2020-07-21  Zhejiang       US  3899211.0
# 82055  2020-07-21       NaN  Germany   203717.0
# 82175  2020-07-21       NaN       US  3899211.0
# 82299  2020-07-22  Zhejiang  Germany   204276.0
# 82418  2020-07-22  Zhejiang       US  3970121.0
# 82507  2020-07-22       NaN  Germany   204276.0
# 82627  2020-07-22       NaN       US  3970121.0
# 82749  2020-07-23  Zhejiang  Germany   204881.0
# 82871  2020-07-23  Zhejiang       US  4038816.0
# 82960  2020-07-23       NaN  Germany   204881.0
# 83078  2020-07-23       NaN       US  4038816.0
# 83201  2020-07-24  Zhejiang  Germany   205623.0
# 83323  2020-07-24  Zhejiang       US  4112531.0
# 83412  2020-07-24       NaN  Germany   205623.0
# 83530  2020-07-24       NaN       US  4112531.0
# 83654  2020-07-25  Zhejiang  Germany   206278.0
# 83773  2020-07-25  Zhejiang       US  4178970.0
# 83863  2020-07-25       NaN  Germany   206278.0
# ...

# %%
test_data.groupby(['country']).agg(np.max)
# Out:
#               date  confirmed
# country
# Germany 2020-09-06   251728.0
# US      2020-09-06  6276365.0

# %%
# %load ../src/features/build_features.py
import numpy as np
from sklearn import linear_model


reg = linear_model.LinearRegression(fit_intercept=True)

def get_doubling_time_via_regression(in_array):
    ''' Use a linear regression to approximate the doubling rate
        Parameters:
        ----------
        in_array : pandas.series
        Returns:
        ----------
        Doubling rate: double
    '''

    y = np.array(in_array)
    X = np.arange(-1,2).reshape(-1, 1)

    assert len(in_array)==3
    reg.fit(X,y)
    intercept=reg.intercept_
    slope=reg.coef_

    return intercept/slope


if __name__ == '__main__':
    test_data_reg=np.array([2,4,6])
    result=get_doubling_time_via_regression(test_data_reg)
    print('the test slope is: '+str(result))
# Out:
# the test slope is: [2.]

# %%
test_data.groupby(['state','country']).agg(np.max)
# Out:
#                        date  confirmed
# state    country
# Zhejiang Germany 2020-09-06   251728.0
#          US      2020-09-06  6276365.0

# %%
def rolling_reg(df_input,col='confirmed'):
    
    days_back=3
    result=df_input[col].rolling(
                       window=days_back,
                       min_periods=days_back).apply(get_doubling_time_via_regression,raw=False)
    return result

# %%
test_data[['state','country','confirmed']].groupby(['state','country']).apply(rolling_reg, 'confirmed')
# Out:
# state     country
# Zhejiang  Germany  81846            NaN
#                    82299            NaN
#                    82749     351.016037
#                    83201     304.271220
#                    83654     294.336435
#                    84105     394.998723
#                    84557     495.649081
#                    85010     398.388462
#                    85463     289.802417
#                    85913     228.223195
#                    86365     226.112610
#                    86818     286.140136
#                    87270     513.701989
#                    87721     382.360458
#                    88175     263.747512
#                    88625     212.804529
#                    89079     193.571536
#                    89529     206.544407
#                    89981     231.809013
#                    90435     397.061661
#                    90888     271.110696
#                    91338     194.001184
#                    91790     186.844463
# ...

# %%
pd_JH_data[['state','country','confirmed']].groupby(['state','country']).apply(rolling_reg, 'confirmed')
# Out:
# state     country
# Alberta   Canada    351              NaN
#                     801              NaN
#                     1252             NaN
#                     1704             NaN
#                     2157             NaN
#                                  ...
# Zhejiang  Zimbabwe  101390     93.115839
#                     101811    111.344538
#                     102294     67.514238
#                     102684     85.333333
#                     103507           inf
# Name: confirmed, Length: 60914, dtype: float64

# %%
pd_DR_result=pd_JH_data[['state','country','confirmed']].groupby(['state','country']).apply(rolling_reg, 'confirmed').reset_index()

# %%
pd_DR_result=pd_DR_result.rename(columns={'confirmed':'doubling rate', 'level_2':'index'})
pd_DR_result.head()
# Out:
#      state country  index  doubling rate
# 0  Alberta  Canada    351            NaN
# 1  Alberta  Canada    801            NaN
# 2  Alberta  Canada   1252            NaN
# 3  Alberta  Canada   1704            NaN
# 4  Alberta  Canada   2157            NaN

# %%
pd_JH_data=pd_JH_data.reset_index()
pd_JH_data.head()
# Out:
#    index       date     state        country  confirmed
# 0      0 2020-01-22       NaN    Afghanistan        0.0
# 1      1 2020-01-22  Zhejiang           Cuba        0.0
# 2      2 2020-01-22  Zhejiang        Croatia        0.0
# 3      3 2020-01-22  Zhejiang  Cote d'Ivoire        0.0
# 4      4 2020-01-22  Zhejiang     Costa Rica        0.0

# %%
pd_result_larg=pd.merge(pd_JH_data,pd_DR_result[['index','doubling rate']],on=['index'],how='left')

# %%
pd_result_larg
# Out:
#          index       date     state                           country  \
# 0            0 2020-01-22       NaN                       Afghanistan
# 1            1 2020-01-22  Zhejiang                              Cuba
# 2            2 2020-01-22  Zhejiang                           Croatia
# 3            3 2020-01-22  Zhejiang                     Cote d'Ivoire
# 4            4 2020-01-22  Zhejiang                        Costa Rica
# ...        ...        ...       ...                               ...
# 103503  103503 2020-09-06       NaN                        San Marino
# 103504  103504 2020-09-06       NaN  Saint Vincent and the Grenadines
# 103505  103505 2020-09-06       NaN                       Saint Lucia
# 103506  103506 2020-09-06       NaN                       Timor-Leste
# 103507  103507 2020-09-06  Zhejiang                          Zimbabwe
#
#         confirmed  doubling rate
# 0             0.0            NaN
# 1             0.0            NaN
# ...
